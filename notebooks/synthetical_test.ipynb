# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import json
import pathlib
import matplotlib.pyplot as plt
import datetime as dt
import ipywidgets as widgets
from soilgasflux_fcs import synthetic_create

# %%
a = synthetic_create.Generator(total_time=180, c0=430)

# %%
a.alpha_cs_plot(alpha_min=1e-5, alpha_max=1e-2,
                cs_min=1e3, cs_max=1e6,
                n=100)
# Out:
# (3154,)
# /Users/alexnaokiasatokobayashi/git/soilgasflux_fcs/notebooks/../soilgasflux_fcs/synthetic_create.py:167: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
a.cc_curve_plot(selected_dcdt=1)
# Out:
# 28

# %%
100%2
# Out:
# 0

# %%
e
